# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
data_root = '/opt/ml/mergeset'
with open(f'{data_root}/ufo/train.json','r') as f:
    datas = json.load(f)

# %%
datas = datas['images']

# %% [markdown]
# ## error 가 발생하는 파일

# %% [markdown]
#  - 아래 error 는 polygon(좌표가 5개 이상) 인 경우의 에러로 확인되었음
#  - ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (N,) + inhomogeneous part.

# %%
error_file = ['img_4627.jpg', 'IMG_7317.jpeg', 'IMG_5158.jpeg','IMG_6776.JPG', 'IMG_5260.jpeg','img_4608.jpg', 'IMG_7172.jpeg', '20210916_143140.jpeg', 
              '20210926_152833.jpg', '20210919_152531.jpg', '20210913_004956.jpg', '20200317_153728.jpg', 'img_4249.jpg', '1631619225806-6.jpg',
              '1632025728267-5.jpg','IMG_0830.jpg','20181128_013531.jpg', '1632648100900.jpg', 'img_4137.jpg', '20210915_145314.jpeg', '20210916_203511.jpeg',
              'img_4636.jpg', 'IMG_0882.jpg', '20210914_193637.jpeg', '20210914_193410.jpeg', '20200823_212502.jpg', 'IMG_4350.jpg', '20210915_183402.jpeg']
idx = -2
image = cv2.imread(f'{data_root}/images/{error_file[idx]}')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
point_list = []
for item in datas[error_file[idx]]['words']:
    points = datas[error_file[idx]]['words'][item]['points']
    point_list.append(np.array(points, dtype=np.int32))
    print(f"{item}: len(points): {len(points)} , {points}, illegibility : {datas[error_file[idx]]['words'][item]['illegibility']}")
image = cv2.polylines(image, point_list, True, (255,0,0), 5)
plt.imshow(image)
# Out:
# 0: len(points): 4 , [[1994.5, 388.5], [2159.5, 453.5], [2194.5, 638.5], [2014.5, 573.5]], illegibility : False
# 1: len(points): 4 , [[2019.5, 583.5], [2204.5, 643.5], [2179.5, 723.5], [2014.5, 663.5]], illegibility : False
# 2: len(points): 12 , [[774.5, 1678.5], [879.5, 1558.5], [1004.5, 1418.5], [1144.5, 1273.5], [1384.5, 1083.5], [1639.5, 913.5], [1744.5, 1208.5], [1534.5, 1378.5], [1309.5, 1533.5], [1089.5, 1688.5], [974.5, 1813.5], [824.5, 1933.5]], illegibility : False
# 3: len(points): 6 , [[819.5, 1988.5], [1309.5, 1573.5], [1924.5, 1228.5], [2029.5, 2173.5], [1569.5, 2558.5], [1054.5, 2808.5]], illegibility : False
# 4: len(points): 4 , [[1144.5, 3038.5], [1514.5, 3058.5], [1489.5, 3293.5], [1139.5, 3268.5]], illegibility : False
# 5: len(points): 4 , [[1709.5, 3068.5], [1849.5, 3053.5], [1834.5, 3253.5], [1704.5, 3258.5]], illegibility : False
# 6: len(points): 4 , [[1824.5, 2998.5], [1999.5, 2953.5], [1964.5, 3188.5], [1819.5, 3213.5]], illegibility : False
# ...

# %% [markdown]
# ## 정상

# %%
normal_file = ['img_4392.jpg', '20210926_184218.jpg']
n_idx = 1
image= cv2.imread(f'{data_root}/images/{normal_file[n_idx]}')
image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
datas[normal_file[n_idx]]
# Out:
# {'paragraphs': {},
#  'words': {'0': {'points': [[438.5, 549.5],
#     [608.5, 549.5],
#     [608.5, 604.5],
#     [438.5, 604.5]],
#    'orientation': 'Horizontal',
#    'transcription': '1403',
#    'word_tags': ['embossing'],
#    'language': ['Others'],
#    'illegibility': False},
#   '1': {'points': [[1363.5, 549.5],
#     [1533.5, 549.5],
#     [1533.5, 609.5],
#     [1363.5, 609.5]],
#    'orientation': 'Horizontal',
#    'transcription': '1405',
#    'word_tags': ['embossing'],
#    'language': ['Others'],
#    'illegibility': False},
#   '2': {'points': [[2298.5, 529.5],
#     [2468.5, 529.5],
#     [2468.5, 589.5],
#     [2298.5, 589.5]],
#    'orientation': 'Horizontal',
#    'transcription': '1406',
#    'word_tags': ['embossing'],
#    'language': ['Others'],
#    'illegibility': False},
#   '3': {'points': [[3253.5, 524.5],
#     [3438.5, 524.5],
#     [3438.5, 574.5],
#     [3253.5, 574.5]],
#    'orientation': 'Horizontal',
#    'transcription': '1503',
# ...
